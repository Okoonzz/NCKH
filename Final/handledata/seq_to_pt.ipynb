# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ================================
# 0. Mount Google Drive
# ================================

import os
import json
import torch
import zipfile

"""
# ================================
# 1. Đường dẫn các file ZIP và thư mục giải nén
# ================================
zip_paths = [
    "/content/drive/MyDrive/KLTN/da_qua_tmp/benign/data_benign_extracted.zip",
    "/content/drive/MyDrive/KLTN/da_qua_tmp/benign/data_benign_extracted1.zip",
    "/content/drive/MyDrive/KLTN/da_qua_tmp/rans2021/data_ransomware_extracted.zip",
    "/content/drive/MyDrive/KLTN/da_qua_tmp/rans2021/data_ransomware_extracted1.zip",
]

# Giải nén ngay tại thư mục chứa zip (như bạn mô tả)
extract_dirs = [
    "/content/drive/MyDrive",
    "/content/drive/MyDrive",
    "/content/drive/MyDrive",
    "/content/drive/MyDrive",
]

for zp, out_dir in zip(zip_paths, extract_dirs):
    if not os.path.isfile(zp):
        print(f"[WARN] Không tìm thấy file zip: {zp}")
        continue
    print(f"[UNZIP] {zp} -> {out_dir}")
    with zipfile.ZipFile(zp, 'r') as zf:
        zf.extractall(out_dir)

print("[INFO] Giải nén xong.")

"""
# ================================
# 2. Khai báo các thư mục JSON sau khi unzip
# ================================
benign_json_dirs = [
]

ransom_json_dirs = [
    "/content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware",
    "/content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware",
]

json_dirs = benign_json_dirs + ransom_json_dirs

# File vocab.json sẽ lưu ở đây
VOCAB_JSON  = "/content/drive/MyDrive/vocab_runtime.json"

# Thư mục chứa các file seq_ids .pt
SEQ_OUT_ROOT = "/content/drive/MyDrive/seq_ids_noise"

MAX_LEN = 1500


# ================================
# 3. Hàm tiện ích
# ================================
def iter_feature_files(json_dirs):
    """Duyệt qua tất cả file .json trong list thư mục json_dirs."""
    for jdir in json_dirs:
        if not os.path.isdir(jdir):
            print(f"[WARN] Không tồn tại thư mục JSON: {jdir}")
            continue
        for fname in os.listdir(jdir):
            if fname.endswith(".json"):
                yield os.path.join(jdir, fname)


def build_tokens_from_features(feat):
    """
    Logic build token giống MultiModalDataset của bạn:
    - api_call_sequence (tối đa 1000 API, giữ thứ tự)
    - behavior_summary
    - dropped_files
    - signatures
    - processes
    - network
    """
    toks = []

    # API chuỗi (giữ thứ tự, giới hạn 1000)
    for call in feat.get("api_call_sequence", [])[:1000]:
        toks.append(f"api:{call.get('api','')}")

    # Feature summary
    for ft, vals in feat.get("behavior_summary", {}).items():
        for v in vals:
            toks.append(f"feature:{ft}:{v}")

    # Dropped files
    for d in feat.get("dropped_files", []):
        if isinstance(d, dict):
            toks.append(f"dropped_file:{d.get('filepath','')}")
        else:
            toks.append(f"dropped_file:{str(d)}")

    # Signatures
    for sig in feat.get("signatures", []):
        toks.append(f"signature:{sig.get('name','')}")

    # Processes
    for p in feat.get("processes", []):
        toks.append(f"process:{p.get('name','')}")

    # Network
    for proto, ents in feat.get("network", {}).items():
        for e in ents:
            if isinstance(e, dict):
                dst  = e.get("dst") or e.get("dst_ip", "")
                port = e.get("dst_port") or e.get("port", "")
                toks.append(f"network:{proto}:{dst}:{port}")
            else:
                toks.append(f"network:{proto}:{e}")

    return toks


# ================================
# 4. Build vocab nếu chưa có
# ================================
if os.path.isfile(VOCAB_JSON):
    print(f"[INFO] Đã có vocab: {VOCAB_JSON} → load dùng luôn.")
    with open(VOCAB_JSON, "r", encoding="utf-8") as f:
        vocab = json.load(f)
else:
    print(f"[INFO] CHƯA có vocab → build mới từ tất cả JSON.")
    vocab = {
        "<PAD>": 0,
        "<UNK>": 1,
    }
    next_idx = 2

    count_files = 0
    for fpath in iter_feature_files(json_dirs):
        count_files += 1
        if count_files % 100 == 0:
            print(f"  [VOCAB] Đang quét file thứ {count_files}: {fpath}")

        with open(fpath, "r", encoding="utf-8") as f:
            feat = json.load(f)

        toks = build_tokens_from_features(feat)
        for t in toks:
            if t not in vocab:
                vocab[t] = next_idx
                next_idx += 1

    os.makedirs(os.path.dirname(VOCAB_JSON), exist_ok=True)
    with open(VOCAB_JSON, "w", encoding="utf-8") as f:
        json.dump(vocab, f, ensure_ascii=False, indent=2)

    print(f"[INFO] Đã build vocab xong, tổng số token = {len(vocab)}")
    print(f"[INFO] Đã lưu vocab vào: {VOCAB_JSON}")


# ================================
# 5. Encode từng JSON → tensor ID [1500] và lưu .pt
# ================================
os.makedirs(SEQ_OUT_ROOT, exist_ok=True)

total = 0
for fpath in iter_feature_files(json_dirs):
    total += 1
    if total % 100 == 0:
        print(f"[SEQ] Đang xử lý file thứ {total}: {fpath}")

    with open(fpath, "r", encoding="utf-8") as f:
        feat = json.load(f)

    toks = build_tokens_from_features(feat)
    toks = toks[:MAX_LEN]  # Cắt 1500

    ids = [vocab.get(t, vocab["<UNK>"]) for t in toks]
    if len(ids) < MAX_LEN:
        ids += [vocab["<PAD>"]] * (MAX_LEN - len(ids))

    # Xác định class để lưu ra thư mục benign / ransomware
    if "/benign/" in fpath:
        cls = "benign"
    elif "/ransomware/" in fpath:
        cls = "ransomware"
    else:
        cls = "unknown"

    out_dir = os.path.join(SEQ_OUT_ROOT, cls)
    os.makedirs(out_dir, exist_ok=True)

    sid = os.path.splitext(os.path.basename(fpath))[0]
    out_path = os.path.join(out_dir, f"{sid}_seq.pt")

    torch.save(torch.tensor(ids, dtype=torch.long), out_path)

print(f"[DONE] Đã encode xong {total} file JSON.")
print(f"[DONE] Các file .pt nằm trong: {SEQ_OUT_ROOT}")
print(f"[DONE] vocab.json nằm ở: {VOCAB_JSON}")
# Out:
# [INFO] Đã có vocab: /content/drive/MyDrive/vocab_runtime.json → load dùng luôn.
# [SEQ] Đang xử lý file thứ 100: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_a9ce99f559c53072a5352da85206ca61886fb313e3257ae0962143c9e4cba54b.json
# [SEQ] Đang xử lý file thứ 200: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_32fbb8c0000889b1e3b1403ed1819cbd27a9fa1294268c18a4eda50298cc541a.json
# [SEQ] Đang xử lý file thứ 300: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_b5481a937541af83aa5d475e6c4ba5c4366f72bcb1244927423a9fcd5b90eba1.json
# [SEQ] Đang xử lý file thứ 400: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_afde4ae62cb234f8bfde8b3171b02d7575f09511b4bcef5c76f711992c028afc.json
# [SEQ] Đang xử lý file thứ 500: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_0fa50607de79f7876f38074be67f91919901993cbf6607095495ba102f35fc8b.json
# [SEQ] Đang xử lý file thứ 600: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_0e8a9b9377a36b913744c7b7cd340f99f4fbf9c4872ddd4b3159ba7da8514df8.json
# [SEQ] Đang xử lý file thứ 700: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_1aef478d6b1a258fc688b2eb9cd6aa3b4aeb87d491f52edfd667b16dde01bafe.json
# [SEQ] Đang xử lý file thứ 800: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_25f7f27f0952284995ade9bf4c331e0a70f271af9e6b9174147d23df8c8e5307.json
# [SEQ] Đang xử lý file thứ 900: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_515bd71a8b3c2bce7b40b89ddfe2e94d332b0779d569c58117f8dcdcb8a91ed9.json
# [SEQ] Đang xử lý file thứ 1000: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_1d05f5bcaab1f706a7ed02e3ca917f6fd96e65d4880c7f31379f3d3fbf59157c.json
# [SEQ] Đang xử lý file thứ 1100: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_1be146c93b95c45d8cd2cca1809d324d2cbe77bd70b3df14ffd41753a6cbd949.json
# [SEQ] Đang xử lý file thứ 1200: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_2810d313317beca3348134989931b3ee72561572233b0486ad77ee0bace99130.json
# [SEQ] Đang xử lý file thứ 1300: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_91af77020646525a94233b3f984180b41824e178ba56a4d4abe8c20f0f90137e.json
# [SEQ] Đang xử lý file thứ 1400: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_2c15914dfc7b4d550459dbff517ce4a59a1dfa7b35eceda59e704edde0b93ab9.json
# [SEQ] Đang xử lý file thứ 1500: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_5f3271f1f17d09a3bd16cc63ad00081a855dd1a6181d3637d346d8291c3a9170.json
# [SEQ] Đang xử lý file thứ 1600: /content/drive/MyDrive/data_ransomware_extracted_noise_2021/ransomware/report_49557408e1e78e6834b1c4edf6b1a377aeb037ec9578d682fcb83b4f1ba64f29.json
# [SEQ] Đang xử lý file thứ 1700: /content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware/report_b3b8b39cc3b28c277b550d2f252b7034236c677f545d6a35e468be758aa5007e.exe.json
# [SEQ] Đang xử lý file thứ 1800: /content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware/report_95bc5b0cf823d89f209035618f596f35267ba24401add2b2561ec795fbe9f1d6.exe.json
# [SEQ] Đang xử lý file thứ 1900: /content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware/report_fc160cb764c8458bb97f587da4023ac790244ecf2f7b7544d611d4b245be451c.exe.json
# [SEQ] Đang xử lý file thứ 2000: /content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware/report_2857269196f820d1cefe17e55a9c9f6cb29fb799550fa57650bc2e8ce0e7d27e.exe.json
# [SEQ] Đang xử lý file thứ 2100: /content/drive/MyDrive/data_ransomware2025_extracted_noise/ransomware/report_933443d4a0fae8938ede0c440e3314283e5e9e4ba32015e9c8c8df1046cebd28.exe.json
# [DONE] Đã encode xong 2189 file JSON.
# [DONE] Các file .pt nằm trong: /content/drive/MyDrive/seq_ids_noise
# [DONE] vocab.json nằm ở: /content/drive/MyDrive/vocab_runtime.json

# %%
import os
import json
import torch
import zipfile

zip_paths = [
    "/content/drive/MyDrive/KLTN/data_junk_api/daquatmp/rans25/data_ransomware2025_extracted_noise.zip",
]

# Giải nén ngay tại thư mục chứa zip (như bạn mô tả)
extract_dirs = [
    "/content/drive/MyDrive",
]

for zp, out_dir in zip(zip_paths, extract_dirs):
    if not os.path.isfile(zp):
        print(f"[WARN] Không tìm thấy file zip: {zp}")
        continue
    print(f"[UNZIP] {zp} -> {out_dir}")
    with zipfile.ZipFile(zp, 'r') as zf:
        zf.extractall(out_dir)

print("[INFO] Giải nén xong.")
# Out:
# [UNZIP] /content/drive/MyDrive/KLTN/data_junk_api/daquatmp/rans25/data_ransomware2025_extracted_noise.zip -> /content/drive/MyDrive
# [INFO] Giải nén xong.

# %%
import os
import json
import torch


# ================================
# 2. Khai báo các thư mục JSON sau khi unzip
# ================================
benign_json_dirs = [
    "/content/drive/MyDrive/data_benign_extracted/benign",
    "/content/drive/MyDrive/data_benign_extracted1/benign",
]

ransom_json_dirs = [
    "/content/drive/MyDrive/data_ransomware_extracted/ransomware",
    "/content/drive/MyDrive/data_ransomware_extracted1/ransomware",
    "/content/drive/MyDrive/data_ransomware_extracted2025/ransomware"
]

json_dirs = benign_json_dirs + ransom_json_dirs

# File vocab.json sẽ lưu ở đây
VOCAB_JSON  = "/content/drive/MyDrive/vocab_runtime.json"

# Thư mục chứa các file seq_ids .pt
SEQ_OUT_ROOT = "/content/drive/MyDrive/seq_ids"

MAX_LEN = 1500


# ================================
# 3. Hàm tiện ích
# ================================
def iter_feature_files(json_dirs):
    """Duyệt qua tất cả file .json trong list thư mục json_dirs."""
    for jdir in json_dirs:
        if not os.path.isdir(jdir):
            print(f"[WARN] Không tồn tại thư mục JSON: {jdir}")
            continue
        for fname in os.listdir(jdir):
            if fname.endswith(".json"):
                yield os.path.join(jdir, fname)


def build_tokens_from_features(feat):
    """
    Logic build token giống MultiModalDataset của bạn:
    - api_call_sequence (tối đa 1000 API, giữ thứ tự)
    - behavior_summary
    - dropped_files
    - signatures
    - processes
    - network
    """
    toks = []

    # API chuỗi (giữ thứ tự, giới hạn 1000)
    for call in feat.get("api_call_sequence", [])[:1000]:
        toks.append(f"api:{call.get('api','')}")

    # Feature summary
    for ft, vals in feat.get("behavior_summary", {}).items():
        for v in vals:
            toks.append(f"feature:{ft}:{v}")

    # Dropped files
    for d in feat.get("dropped_files", []):
        if isinstance(d, dict):
            toks.append(f"dropped_file:{d.get('filepath','')}")
        else:
            toks.append(f"dropped_file:{str(d)}")

    # Signatures
    for sig in feat.get("signatures", []):
        toks.append(f"signature:{sig.get('name','')}")

    # Processes
    for p in feat.get("processes", []):
        toks.append(f"process:{p.get('name','')}")

    # Network
    for proto, ents in feat.get("network", {}).items():
        for e in ents:
            if isinstance(e, dict):
                dst  = e.get("dst") or e.get("dst_ip", "")
                port = e.get("dst_port") or e.get("port", "")
                toks.append(f"network:{proto}:{dst}:{port}")
            else:
                toks.append(f"network:{proto}:{e}")

    return toks


# ================================
# 4. Build vocab nếu chưa có
# ================================
if os.path.isfile(VOCAB_JSON):
    print(f"[INFO] Đã có vocab: {VOCAB_JSON} → load dùng luôn.")
    with open(VOCAB_JSON, "r", encoding="utf-8") as f:
        vocab = json.load(f)
else:
    print(f"[INFO] CHƯA có vocab → build mới từ tất cả JSON.")
    vocab = {
        "<PAD>": 0,
        "<UNK>": 1,
    }
    next_idx = 2

    count_files = 0
    for fpath in iter_feature_files(json_dirs):
        count_files += 1
        if count_files % 100 == 0:
            print(f"  [VOCAB] Đang quét file thứ {count_files}: {fpath}")

        with open(fpath, "r", encoding="utf-8") as f:
            feat = json.load(f)

        toks = build_tokens_from_features(feat)
        for t in toks:
            if t not in vocab:
                vocab[t] = next_idx
                next_idx += 1

    os.makedirs(os.path.dirname(VOCAB_JSON), exist_ok=True)
    with open(VOCAB_JSON, "w", encoding="utf-8") as f:
        json.dump(vocab, f, ensure_ascii=False, indent=2)

    print(f"[INFO] Đã build vocab xong, tổng số token = {len(vocab)}")
    print(f"[INFO] Đã lưu vocab vào: {VOCAB_JSON}")


# ================================
# 5. Encode từng JSON → tensor ID [1500] và lưu .pt
# ================================
os.makedirs(SEQ_OUT_ROOT, exist_ok=True)

total = 0
for fpath in iter_feature_files(json_dirs):
    total += 1
    if total % 100 == 0:
        print(f"[SEQ] Đang xử lý file thứ {total}: {fpath}")

    with open(fpath, "r", encoding="utf-8") as f:
        feat = json.load(f)

    toks = build_tokens_from_features(feat)
    toks = toks[:MAX_LEN]  # Cắt 1500

    ids = [vocab.get(t, vocab["<UNK>"]) for t in toks]
    if len(ids) < MAX_LEN:
        ids += [vocab["<PAD>"]] * (MAX_LEN - len(ids))

    # Xác định class để lưu ra thư mục benign / ransomware
    if "/benign/" in fpath:
        cls = "benign"
    elif "/ransomware/" in fpath:
        cls = "ransomware"
    else:
        cls = "unknown"

    out_dir = os.path.join(SEQ_OUT_ROOT, cls)
    os.makedirs(out_dir, exist_ok=True)

    sid = os.path.splitext(os.path.basename(fpath))[0]
    out_path = os.path.join(out_dir, f"{sid}_seq.pt")

    torch.save(torch.tensor(ids, dtype=torch.long), out_path)

print(f"[DONE] Đã encode xong {total} file JSON.")
print(f"[DONE] Các file .pt nằm trong: {SEQ_OUT_ROOT}")
print(f"[DONE] vocab.json nằm ở: {VOCAB_JSON}")
# Out:
# [INFO] CHƯA có vocab → build mới từ tất cả JSON.
#   [VOCAB] Đang quét file thứ 100: /content/drive/MyDrive/data_benign_extracted/benign/report_BitTorrent Sync.exe.json
#   [VOCAB] Đang quét file thứ 200: /content/drive/MyDrive/data_benign_extracted/benign/report_Garmin WebUpdater.exe.json
#   [VOCAB] Đang quét file thứ 300: /content/drive/MyDrive/data_benign_extracted/benign/report_Nexus.exe.json
#   [VOCAB] Đang quét file thứ 400: /content/drive/MyDrive/data_benign_extracted/benign/report_SuperCopier.exe.json
#   [VOCAB] Đang quét file thứ 500: /content/drive/MyDrive/data_benign_extracted/benign/report_Alien Shooter.exe.json
#   [VOCAB] Đang quét file thứ 600: /content/drive/MyDrive/data_benign_extracted/benign/report_ESET Smart Security.exe.json
#   [VOCAB] Đang quét file thứ 700: /content/drive/MyDrive/data_benign_extracted/benign/report_Magic Photo Editor.exe.json
#   [VOCAB] Đang quét file thứ 800: /content/drive/MyDrive/data_benign_extracted/benign/report_Recuva Data Recovery.exe.json
#   [VOCAB] Đang quét file thứ 900: /content/drive/MyDrive/data_benign_extracted/benign/report_Unknown File Handler.exe.json
#   [VOCAB] Đang quét file thứ 1000: /content/drive/MyDrive/data_benign_extracted/benign/report_WinRAR.exe.json
#   [VOCAB] Đang quét file thứ 1100: /content/drive/MyDrive/data_benign_extracted/benign/report_UniPDF.exe.json
#   [VOCAB] Đang quét file thứ 1200: /content/drive/MyDrive/data_benign_extracted/benign/report_VLC-Lite media player.exe.json
#   [VOCAB] Đang quét file thứ 1300: /content/drive/MyDrive/data_benign_extracted/benign/report_eScan Internet Security.exe.json
#   [VOCAB] Đang quét file thứ 1400: /content/drive/MyDrive/data_benign_extracted/benign/report_Marine Aquarium.exe.json
#   [VOCAB] Đang quét file thứ 1500: /content/drive/MyDrive/data_benign_extracted/benign/report_AlphaGO.exe.json
#   [VOCAB] Đang quét file thứ 1600: /content/drive/MyDrive/data_benign_extracted1/benign/report_329.json
#   [VOCAB] Đang quét file thứ 1700: /content/drive/MyDrive/data_benign_extracted1/benign/report_626.exe.json
#   [VOCAB] Đang quét file thứ 1800: /content/drive/MyDrive/data_benign_extracted1/benign/report_56.json
#   [VOCAB] Đang quét file thứ 1900: /content/drive/MyDrive/data_benign_extracted1/benign/report_212.json
#   [VOCAB] Đang quét file thứ 2000: /content/drive/MyDrive/data_benign_extracted1/benign/report_46.json
#   [VOCAB] Đang quét file thứ 2100: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_6dc9796ac143f98495509bac0f35154badb25fc28be51bd54d32c1a91348615c.json
#   [VOCAB] Đang quét file thứ 2200: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_5d3122a28bc48daa0a9d05a7375aeee1cd28e8d07efc4b6034238000405d61ae.json
#   [VOCAB] Đang quét file thứ 2300: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_2f1bfd7f81d46c8ad8d2dfbbf6cef38df7990d3ec405b3838c4ee464d6a5daec.json
#   [VOCAB] Đang quét file thứ 2400: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_4b4346e10d5f88441925ef756ab4d13ed0dc61bb04be9f3ff4032adcf63246c3.json
#   [VOCAB] Đang quét file thứ 2500: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_338f1797b135dd3254257586c47c0f3aa2e870e912fbac42db3ac404fd1faa1e.json
#   [VOCAB] Đang quét file thứ 2600: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_2f89af5546abd59aa4a78aef947814c10ce25fe9b27422810a0a5884324054ef.json
#   [VOCAB] Đang quét file thứ 2700: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_d9a8437b9af58fbcaba3f226499de826eb55a7f84d58b04fd51ffd1fcfbb3c35.json
#   [VOCAB] Đang quét file thứ 2800: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_aaa69fa4f90db323d998303121975b02d047d5bc052ed6a7f5232c51c9a5d5a8.json
#   [VOCAB] Đang quét file thứ 2900: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_12c631c374759d42c4f347b864750a6c41f0dae1fe66a6108ada7e5c85aeec17.json
#   [VOCAB] Đang quét file thứ 3000: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_14be70f30bd51c74629897e20d965aa90b89acf0eef064778540b9acd7ec6a67.json
#   [VOCAB] Đang quét file thứ 3100: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_1dc8842926a83b63fb48bb000b274340433a69628da8f434ed67f12e461361f4.json
#   [VOCAB] Đang quét file thứ 3200: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_280b3289bd1a5cba0149334997a1c970a54076d552cd4afaf15e785cf4299574.json
#   [VOCAB] Đang quét file thứ 3300: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_a74d1731fedb52e3292ad0978940222097c9b1225d4b4072bc38e3918b7ce524.json
#   [VOCAB] Đang quét file thứ 3400: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_255d5f14289b4e7dfee38f2b2d293dfc2663b4185584c9b1532913fe4c528089.json
#   [VOCAB] Đang quét file thứ 3500: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_012af5a342a2ae0913faafa4637eccaf99145c3aeefefcca6f8b5f317a132a42.json
#   [VOCAB] Đang quét file thứ 3600: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_0a194bfbc1096fda1fc98d73c768cc8f9e6c52abfec76ee166d1b535e2f89902.json
#   [VOCAB] Đang quét file thứ 3700: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_69775389eb0207fec3a3f5649a0ad9315856c810f595c086ac49d68cdbc1d136.json
#   [VOCAB] Đang quét file thứ 3800: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_e525bc376016b4bd2d6dd2e05aac14765bbd2e384bbdee9b9d67e4990e05c196.exe.json
#   [VOCAB] Đang quét file thứ 3900: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_8fb025d59e501a545cae40ef222ca22b5722fdd487cdefb3f2e4b0a8635f9bc2.exe.json
#   [VOCAB] Đang quét file thứ 4000: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_7f4a4a2093163e8946b5649b91c942d414779bec4551613cd35a812d6c9359f5.exe.json
#   [VOCAB] Đang quét file thứ 4100: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_e73605374d40933b78ad13d7053d656f373b285efb6a3ab89ae6cd80191f0778.exe.json
#   [VOCAB] Đang quét file thứ 4200: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_34c843387845479329052ec7a71f6445c7530b6fee2eabb458da2338d1af41e4.exe.json
# [INFO] Đã build vocab xong, tổng số token = 4509056
# [INFO] Đã lưu vocab vào: /content/drive/MyDrive/vocab_runtime.json
# [SEQ] Đang xử lý file thứ 100: /content/drive/MyDrive/data_benign_extracted/benign/report_BitTorrent Sync.exe.json
# [SEQ] Đang xử lý file thứ 200: /content/drive/MyDrive/data_benign_extracted/benign/report_Garmin WebUpdater.exe.json
# [SEQ] Đang xử lý file thứ 300: /content/drive/MyDrive/data_benign_extracted/benign/report_Nexus.exe.json
# [SEQ] Đang xử lý file thứ 400: /content/drive/MyDrive/data_benign_extracted/benign/report_SuperCopier.exe.json
# [SEQ] Đang xử lý file thứ 500: /content/drive/MyDrive/data_benign_extracted/benign/report_Alien Shooter.exe.json
# [SEQ] Đang xử lý file thứ 600: /content/drive/MyDrive/data_benign_extracted/benign/report_ESET Smart Security.exe.json
# [SEQ] Đang xử lý file thứ 700: /content/drive/MyDrive/data_benign_extracted/benign/report_Magic Photo Editor.exe.json
# [SEQ] Đang xử lý file thứ 800: /content/drive/MyDrive/data_benign_extracted/benign/report_Recuva Data Recovery.exe.json
# [SEQ] Đang xử lý file thứ 900: /content/drive/MyDrive/data_benign_extracted/benign/report_Unknown File Handler.exe.json
# [SEQ] Đang xử lý file thứ 1000: /content/drive/MyDrive/data_benign_extracted/benign/report_WinRAR.exe.json
# [SEQ] Đang xử lý file thứ 1100: /content/drive/MyDrive/data_benign_extracted/benign/report_UniPDF.exe.json
# [SEQ] Đang xử lý file thứ 1200: /content/drive/MyDrive/data_benign_extracted/benign/report_VLC-Lite media player.exe.json
# [SEQ] Đang xử lý file thứ 1300: /content/drive/MyDrive/data_benign_extracted/benign/report_eScan Internet Security.exe.json
# [SEQ] Đang xử lý file thứ 1400: /content/drive/MyDrive/data_benign_extracted/benign/report_Marine Aquarium.exe.json
# [SEQ] Đang xử lý file thứ 1500: /content/drive/MyDrive/data_benign_extracted/benign/report_AlphaGO.exe.json
# [SEQ] Đang xử lý file thứ 1600: /content/drive/MyDrive/data_benign_extracted1/benign/report_329.json
# [SEQ] Đang xử lý file thứ 1700: /content/drive/MyDrive/data_benign_extracted1/benign/report_626.exe.json
# [SEQ] Đang xử lý file thứ 1800: /content/drive/MyDrive/data_benign_extracted1/benign/report_56.json
# [SEQ] Đang xử lý file thứ 1900: /content/drive/MyDrive/data_benign_extracted1/benign/report_212.json
# [SEQ] Đang xử lý file thứ 2000: /content/drive/MyDrive/data_benign_extracted1/benign/report_46.json
# [SEQ] Đang xử lý file thứ 2100: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_6dc9796ac143f98495509bac0f35154badb25fc28be51bd54d32c1a91348615c.json
# [SEQ] Đang xử lý file thứ 2200: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_5d3122a28bc48daa0a9d05a7375aeee1cd28e8d07efc4b6034238000405d61ae.json
# [SEQ] Đang xử lý file thứ 2300: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_2f1bfd7f81d46c8ad8d2dfbbf6cef38df7990d3ec405b3838c4ee464d6a5daec.json
# [SEQ] Đang xử lý file thứ 2400: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_4b4346e10d5f88441925ef756ab4d13ed0dc61bb04be9f3ff4032adcf63246c3.json
# [SEQ] Đang xử lý file thứ 2500: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_338f1797b135dd3254257586c47c0f3aa2e870e912fbac42db3ac404fd1faa1e.json
# [SEQ] Đang xử lý file thứ 2600: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_2f89af5546abd59aa4a78aef947814c10ce25fe9b27422810a0a5884324054ef.json
# [SEQ] Đang xử lý file thứ 2700: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_d9a8437b9af58fbcaba3f226499de826eb55a7f84d58b04fd51ffd1fcfbb3c35.json
# [SEQ] Đang xử lý file thứ 2800: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_aaa69fa4f90db323d998303121975b02d047d5bc052ed6a7f5232c51c9a5d5a8.json
# [SEQ] Đang xử lý file thứ 2900: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_12c631c374759d42c4f347b864750a6c41f0dae1fe66a6108ada7e5c85aeec17.json
# [SEQ] Đang xử lý file thứ 3000: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_14be70f30bd51c74629897e20d965aa90b89acf0eef064778540b9acd7ec6a67.json
# [SEQ] Đang xử lý file thứ 3100: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_1dc8842926a83b63fb48bb000b274340433a69628da8f434ed67f12e461361f4.json
# [SEQ] Đang xử lý file thứ 3200: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_280b3289bd1a5cba0149334997a1c970a54076d552cd4afaf15e785cf4299574.json
# [SEQ] Đang xử lý file thứ 3300: /content/drive/MyDrive/data_ransomware_extracted/ransomware/report_a74d1731fedb52e3292ad0978940222097c9b1225d4b4072bc38e3918b7ce524.json
# [SEQ] Đang xử lý file thứ 3400: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_255d5f14289b4e7dfee38f2b2d293dfc2663b4185584c9b1532913fe4c528089.json
# [SEQ] Đang xử lý file thứ 3500: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_012af5a342a2ae0913faafa4637eccaf99145c3aeefefcca6f8b5f317a132a42.json
# [SEQ] Đang xử lý file thứ 3600: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_0a194bfbc1096fda1fc98d73c768cc8f9e6c52abfec76ee166d1b535e2f89902.json
# [SEQ] Đang xử lý file thứ 3700: /content/drive/MyDrive/data_ransomware_extracted1/ransomware/report_69775389eb0207fec3a3f5649a0ad9315856c810f595c086ac49d68cdbc1d136.json
# [SEQ] Đang xử lý file thứ 3800: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_e525bc376016b4bd2d6dd2e05aac14765bbd2e384bbdee9b9d67e4990e05c196.exe.json
# [SEQ] Đang xử lý file thứ 3900: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_8fb025d59e501a545cae40ef222ca22b5722fdd487cdefb3f2e4b0a8635f9bc2.exe.json
# [SEQ] Đang xử lý file thứ 4000: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_7f4a4a2093163e8946b5649b91c942d414779bec4551613cd35a812d6c9359f5.exe.json
# [SEQ] Đang xử lý file thứ 4100: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_e73605374d40933b78ad13d7053d656f373b285efb6a3ab89ae6cd80191f0778.exe.json
# [SEQ] Đang xử lý file thứ 4200: /content/drive/MyDrive/data_ransomware_extracted2025/ransomware/report_34c843387845479329052ec7a71f6445c7530b6fee2eabb458da2338d1af41e4.exe.json
# [DONE] Đã encode xong 4259 file JSON.
# [DONE] Các file .pt nằm trong: /content/drive/MyDrive/seq_ids
# [DONE] vocab.json nằm ở: /content/drive/MyDrive/vocab_runtime.json

# %%
import os

folder = "/content/drive/MyDrive/seq_ids/benign"

for filename in os.listdir(folder):
    if "&" in filename:
        old_path = os.path.join(folder, filename)

        # Xóa ký tự &
        new_filename = filename.replace("&", "")
        # Đồng thời strip khoảng trắng dư thừa
        new_filename = new_filename.replace("  ", " ").strip()

        new_path = os.path.join(folder, new_filename)

        os.rename(old_path, new_path)
        print(f"Đổi tên: {filename}  →  {new_filename}")

print("Hoàn tất!")
# Out:
# Đổi tên: report_Tag&Rename.exe_seq.pt  →  report_TagRename.exe_seq.pt
# Đổi tên: report_Driver & Application Installation.exe_seq.pt  →  report_Driver Application Installation.exe_seq.pt
# Đổi tên: report_Dell Help & Support.exe_seq.pt  →  report_Dell Help Support.exe_seq.pt
# Đổi tên: report_Saints & Sinners Bingo.exe_seq.pt  →  report_Saints Sinners Bingo.exe_seq.pt
# Đổi tên: report_Command & Conquer_ Generals.exe_seq.pt  →  report_Command Conquer_ Generals.exe_seq.pt
# Đổi tên: report_Aurora 3D Text & Logo Maker.exe_seq.pt  →  report_Aurora 3D Text Logo Maker.exe_seq.pt
# Hoàn tất!
